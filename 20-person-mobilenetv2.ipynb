# %%
import os
import shutil
import random

# === CONFIGURATION ===
SOURCE_DIR = r"/kaggle/input/full-dataset-20person/NEW_DataSet_20_person"  # 👈 Your dataset path
DEST_ROOT = "./kfold_dataset_14_3_3"
CLASS_MAP = {
    "Left_eye": "left",
    "Right_eye": "right",
    "Forward_eye": "forward",
    "Close_eye": "close"
}
RANDOM_SEED = 42
random.seed(RANDOM_SEED)

# === Get all person IDs
sample_class = list(CLASS_MAP.keys())[0]
sample_dir = os.path.join(SOURCE_DIR, sample_class)
all_persons = sorted([p for p in os.listdir(sample_dir) if os.path.isdir(os.path.join(sample_dir, p))])
assert len(all_persons) == 20, f"Expected 20 persons, found {len(all_persons)}"

# === Shuffle and split persons into 4 folds of 3 test persons each
random.shuffle(all_persons)
test_folds = [all_persons[i::4] for i in range(4)]  # 5 test sets, pick 3 for each

for fold_index in range(4):
    test_persons = test_folds[fold_index][:3]
    remaining = [p for p in all_persons if p not in test_persons]

    val_persons = random.sample(remaining, 3)
    train_persons = [p for p in remaining if p not in val_persons]

    print(f"\n📂 Fold {fold_index + 1}")
    print(f"   Train Persons: {train_persons}")
    print(f"   Val Persons:   {val_persons}")
    print(f"   Test Persons:  {test_persons}")

    # === Copy files into structured folders
    for split, persons in [("train", train_persons), ("val", val_persons), ("test", test_persons)]:
        for class_folder, class_name in CLASS_MAP.items():
            for person_id in persons:
                src_dir = os.path.join(SOURCE_DIR, class_folder, person_id)
                dst_dir = os.path.join(DEST_ROOT, f"fold_{fold_index + 1}", split, class_name)
                os.makedirs(dst_dir, exist_ok=True)
                for file in os.listdir(src_dir):
                    shutil.copy2(
                        os.path.join(src_dir, file),
                        os.path.join(dst_dir, file)
                    )

print("\n✅ 4 folds with 14 train / 3 val / 3 test persons each created at:", DEST_ROOT)
# Out:
# 📂 Fold 1
#    Train Persons: ['p06', 'p15', 'p05', 'p16', 'p19', 'p18', 'p11', 'p02', 'p12', 'p03', 'p17', 'p09', 'p01', 'p04']
#    Val Persons:   ['p13', 'p08', 'p14']
#    Test Persons:  ['p20', 'p10', 'p07']
#
# 📂 Fold 2
#    Train Persons: ['p20', 'p15', 'p05', 'p10', 'p16', 'p19', 'p07', 'p18', 'p02', 'p12', 'p03', 'p08', 'p01', 'p04']
#    Val Persons:   ['p09', 'p11', 'p17']
#    Test Persons:  ['p06', 'p14', 'p13']
#
# 📂 Fold 3
#    Train Persons: ['p06', 'p05', 'p10', 'p14', 'p07', 'p13', 'p11', 'p02', 'p12', 'p17', 'p08', 'p09', 'p01', 'p04']
#    Val Persons:   ['p20', 'p19', 'p03']
#    Test Persons:  ['p15', 'p16', 'p18']
#
# 📂 Fold 4
#    Train Persons: ['p20', 'p06', 'p15', 'p10', 'p16', 'p07', 'p13', 'p18', 'p02', 'p03', 'p17', 'p09', 'p01', 'p04']
#    Val Persons:   ['p08', 'p12', 'p14']
#    Test Persons:  ['p05', 'p19', 'p11']
#
# ✅ 4 folds with 14 train / 3 val / 3 test persons each created at: ./kfold_dataset_14_3_3

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint

from sklearn.metrics import classification_report, confusion_matrix, f1_score
import seaborn as sns
import matplotlib.pyplot as plt

# === CONFIGURATION ===
IMG_SIZE = 224
BATCH_SIZE = 16
EPOCHS_PHASE1 = 50
EPOCHS_PHASE2 = 50
FOLDS = 4
FOLD_PATH = "./kfold_dataset_14_3_3"

# === Learning rate scheduler (Cosine Decay) ===
def cosine_decay(epoch):
    max_lr = 1e-3
    min_lr = 1e-6
    return float(min_lr + 0.5 * (max_lr - min_lr) * (1 + np.cos(np.pi * epoch / EPOCHS_PHASE1)))

# === Data Augmentation ===
train_aug = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    zoom_range=0.2,
    brightness_range=[0.6, 1.4],
    width_shift_range=0.1,
    height_shift_range=0.1
)
val_aug = ImageDataGenerator(rescale=1./255)

# === Store accuracy results
fold_accuracies = []

# === CLASS LABELS (based on directory names)
class_names = ['close', 'forward', 'left', 'right']

# === Train and evaluate on each fold
for i in range(1, FOLDS + 1):
    print(f"\n🔁 Training on Fold {i}/{FOLDS}")

    train_data = train_aug.flow_from_directory(
        os.path.join(FOLD_PATH, f"fold_{i}", "train"),
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True
    )

    val_data = val_aug.flow_from_directory(
        os.path.join(FOLD_PATH, f"fold_{i}", "val"),
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False
    )

    test_data = val_aug.flow_from_directory(
        os.path.join(FOLD_PATH, f"fold_{i}", "test"),
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False
    )

    # === Build model
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
    base_model.trainable = False  # Phase 1 frozen

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.3)(x)
    output = Dense(4, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=output)

    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    checkpoint1 = ModelCheckpoint(
        f'model_fold_{i}_phase1.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )

    print("🔼 Phase 1: Training classification head...")
    model.fit(
        train_data,
        validation_data=val_data,
        epochs=EPOCHS_PHASE1,
        callbacks=[
            LearningRateScheduler(cosine_decay),
            EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
            checkpoint1
        ],
        verbose=1
    )

    # === Phase 2: Fine-tune
    print("🔁 Phase 2: Fine-tuning top 30 base layers...")
    for layer in base_model.layers[-30:]:
        layer.trainable = True

    model.compile(
        optimizer=Adam(learning_rate=2e-5),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    checkpoint2 = ModelCheckpoint(
        f'model_fold_{i}_fine_tuned.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )

    model.fit(
        train_data,
        validation_data=val_data,
        epochs=EPOCHS_PHASE2,
        callbacks=[
            EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
            checkpoint2
        ],
        verbose=1
    )

    # === Evaluate on test set ===
    print("🧪 Evaluating on test set...")
    predictions = model.predict(test_data, verbose=1)
    y_pred = np.argmax(predictions, axis=1)
    y_true = test_data.classes

    print("📋 Classification Report:")
    report = classification_report(y_true, y_pred, target_names=class_names, digits=4)
    print(report)

    cm = confusion_matrix(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='macro')
    acc = np.mean(y_true == y_pred)

    fold_accuracies.append(acc)

    # === Save confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Fold {i} - Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.tight_layout()
    plt.savefig(f'confusion_matrix_fold_{i}.png')
    plt.close()

    with open(f"classification_report_fold_{i}.txt", "w") as f:
        f.write(report)
        f.write(f"\nF1 Score: {f1:.4f}")
        f.write(f"\nAccuracy: {acc:.4f}")

    print(f"✅ Fold {i} Test Accuracy: {acc:.4f} | F1 Score: {f1:.4f}")

# === Final summary
mean_acc = np.mean(fold_accuracies)
std_acc = np.std(fold_accuracies)
print(f"\n📊 Average Test Accuracy across {FOLDS} folds: {mean_acc:.4f} ± {std_acc:.4f}")
# Out:
# 2025-05-13 20:19:35.714524: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747167575.914307      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747167575.980717      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 🔁 Training on Fold 1/4
# Found 2777 images belonging to 4 classes.
# Found 595 images belonging to 4 classes.
# Found 597 images belonging to 4 classes.
# I0000 00:00:1747167590.011421      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# 🔼 Phase 1: Training classification head...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747167601.143125     116 service.cc:148] XLA service 0x7cb1b40025a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747167601.143966     116 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1747167601.982778     116 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/174 ━━━━━━━━━━━━━━━━━━━━ 33:28 12s/step - accuracy: 0.3125 - loss: 1.6974
# I0000 00:00:1747167605.645773     116 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.5308 - loss: 1.1748
# Epoch 1: val_accuracy improved from -inf to 0.81849, saving model to model_fold_1_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 53s 237ms/step - accuracy: 0.5315 - loss: 1.1736 - val_accuracy: 0.8185 - val_loss: 0.7140 - learning_rate: 0.0010
# Epoch 2/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7623 - loss: 0.7983
# Epoch 2: val_accuracy improved from 0.81849 to 0.89244, saving model to model_fold_1_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.7625 - loss: 0.7980 - val_accuracy: 0.8924 - val_loss: 0.6296 - learning_rate: 9.9901e-04
# Epoch 3/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8431 - loss: 0.6610
# Epoch 3: val_accuracy improved from 0.89244 to 0.91261, saving model to model_fold_1_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.8431 - loss: 0.6609 - val_accuracy: 0.9126 - val_loss: 0.5866 - learning_rate: 9.9606e-04
# Epoch 4/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8739 - loss: 0.6330
# Epoch 4: val_accuracy did not improve from 0.91261
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 182ms/step - accuracy: 0.8740 - loss: 0.6329 - val_accuracy: 0.9059 - val_loss: 0.6172 - learning_rate: 9.9115e-04
# Epoch 5/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8919 - loss: 0.6074
# Epoch 5: val_accuracy did not improve from 0.91261
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 186ms/step - accuracy: 0.8919 - loss: 0.6074 - val_accuracy: 0.9059 - val_loss: 0.5846 - learning_rate: 9.8431e-04
# Epoch 6/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8965 - loss: 0.5825
# Epoch 6: val_accuracy improved from 0.91261 to 0.91933, saving model to model_fold_1_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.8966 - loss: 0.5824 - val_accuracy: 0.9193 - val_loss: 0.5803 - learning_rate: 9.7555e-04
# Epoch 7/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9147 - loss: 0.5636
# Epoch 7: val_accuracy did not improve from 0.91933
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9147 - loss: 0.5636 - val_accuracy: 0.9059 - val_loss: 0.5888 - learning_rate: 9.6492e-04
# Epoch 8/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9266 - loss: 0.5428
# Epoch 8: val_accuracy improved from 0.91933 to 0.92605, saving model to model_fold_1_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.9266 - loss: 0.5429 - val_accuracy: 0.9261 - val_loss: 0.5676 - learning_rate: 9.5246e-04
# Epoch 9/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8881 - loss: 0.5772
# Epoch 9: val_accuracy did not improve from 0.92605
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.8882 - loss: 0.5772 - val_accuracy: 0.9227 - val_loss: 0.5741 - learning_rate: 9.3822e-04
# Epoch 10/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9144 - loss: 0.5649
# Epoch 10: val_accuracy improved from 0.92605 to 0.92941, saving model to model_fold_1_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 188ms/step - accuracy: 0.9144 - loss: 0.5648 - val_accuracy: 0.9294 - val_loss: 0.5497 - learning_rate: 9.2224e-04
# Epoch 11/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9153 - loss: 0.5410
# Epoch 11: val_accuracy did not improve from 0.92941
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9153 - loss: 0.5410 - val_accuracy: 0.8773 - val_loss: 0.5814 - learning_rate: 9.0460e-04
# Epoch 12/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9204 - loss: 0.5504
# Epoch 12: val_accuracy did not improve from 0.92941
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9204 - loss: 0.5504 - val_accuracy: 0.8689 - val_loss: 0.6001 - learning_rate: 8.8537e-04
# Epoch 13/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9162 - loss: 0.5512
# Epoch 13: val_accuracy did not improve from 0.92941
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9162 - loss: 0.5511 - val_accuracy: 0.9092 - val_loss: 0.5640 - learning_rate: 8.6462e-04
# Epoch 14/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9227 - loss: 0.5374
# Epoch 14: val_accuracy did not improve from 0.92941
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9227 - loss: 0.5374 - val_accuracy: 0.9008 - val_loss: 0.5817 - learning_rate: 8.4243e-04
# Epoch 15/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9214 - loss: 0.5331
# Epoch 15: val_accuracy did not improve from 0.92941
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9214 - loss: 0.5331 - val_accuracy: 0.9109 - val_loss: 0.5692 - learning_rate: 8.1889e-04
# 🔁 Phase 2: Fine-tuning top 30 base layers...
# Epoch 1/50
# E0000 00:00:1747168113.142383     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747168113.339720     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747168113.535105     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 110/174 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.6971 - loss: 1.0221
# E0000 00:00:1747168138.765883     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747168138.964731     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747168139.160034     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.7320 - loss: 0.9492
# Epoch 1: val_accuracy improved from -inf to 0.88571, saving model to model_fold_1_fine_tuned.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 62s 247ms/step - accuracy: 0.7324 - loss: 0.9483 - val_accuracy: 0.8857 - val_loss: 0.6067
# Epoch 2/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9001 - loss: 0.5957
# Epoch 2: val_accuracy improved from 0.88571 to 0.90588, saving model to model_fold_1_fine_tuned.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 189ms/step - accuracy: 0.9001 - loss: 0.5958 - val_accuracy: 0.9059 - val_loss: 0.5955
# Epoch 3/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9254 - loss: 0.5615
# Epoch 3: val_accuracy did not improve from 0.90588
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 186ms/step - accuracy: 0.9254 - loss: 0.5614 - val_accuracy: 0.8840 - val_loss: 0.6924
# Epoch 4/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9373 - loss: 0.5317
# Epoch 4: val_accuracy did not improve from 0.90588
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9373 - loss: 0.5317 - val_accuracy: 0.8975 - val_loss: 0.6453
# Epoch 5/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9645 - loss: 0.4912
# Epoch 5: val_accuracy did not improve from 0.90588
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9645 - loss: 0.4913 - val_accuracy: 0.8941 - val_loss: 0.6521
# 🧪 Evaluating on test set...
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#        close     1.0000    1.0000    1.0000       150
#      forward     0.8797    0.7959    0.8357       147
#         left     0.9691    0.6267    0.7611       150
#        right     0.6544    0.9467    0.7738       150
#
#     accuracy                         0.8425       597
#    macro avg     0.8758    0.8423    0.8427       597
# weighted avg     0.8758    0.8425    0.8427       597
#
# ✅ Fold 1 Test Accuracy: 0.8425 | F1 Score: 0.8427
#
# 🔁 Training on Fold 2/4
# Found 2778 images belonging to 4 classes.
# Found 595 images belonging to 4 classes.
# Found 596 images belonging to 4 classes.
# 🔼 Phase 1: Training classification head...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.5722 - loss: 1.1386
# Epoch 1: val_accuracy improved from -inf to 0.59496, saving model to model_fold_2_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 50s 234ms/step - accuracy: 0.5727 - loss: 1.1375 - val_accuracy: 0.5950 - val_loss: 1.0815 - learning_rate: 0.0010
# Epoch 2/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8008 - loss: 0.7455
# Epoch 2: val_accuracy improved from 0.59496 to 0.67395, saving model to model_fold_2_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 190ms/step - accuracy: 0.8009 - loss: 0.7452 - val_accuracy: 0.6739 - val_loss: 0.8728 - learning_rate: 9.9901e-04
# Epoch 3/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8435 - loss: 0.6655
# Epoch 3: val_accuracy improved from 0.67395 to 0.70252, saving model to model_fold_2_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.8435 - loss: 0.6654 - val_accuracy: 0.7025 - val_loss: 0.7945 - learning_rate: 9.9606e-04
# Epoch 4/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8746 - loss: 0.6191
# Epoch 4: val_accuracy improved from 0.70252 to 0.78487, saving model to model_fold_2_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 188ms/step - accuracy: 0.8746 - loss: 0.6191 - val_accuracy: 0.7849 - val_loss: 0.7069 - learning_rate: 9.9115e-04
# Epoch 5/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8689 - loss: 0.6195
# Epoch 5: val_accuracy did not improve from 0.78487
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.8689 - loss: 0.6195 - val_accuracy: 0.7345 - val_loss: 0.8188 - learning_rate: 9.8431e-04
# Epoch 6/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8977 - loss: 0.5879
# Epoch 6: val_accuracy did not improve from 0.78487
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 186ms/step - accuracy: 0.8977 - loss: 0.5879 - val_accuracy: 0.7025 - val_loss: 0.8446 - learning_rate: 9.7555e-04
# Epoch 7/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9109 - loss: 0.5728
# Epoch 7: val_accuracy did not improve from 0.78487
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9109 - loss: 0.5728 - val_accuracy: 0.7496 - val_loss: 0.7453 - learning_rate: 9.6492e-04
# Epoch 8/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9116 - loss: 0.5687
# Epoch 8: val_accuracy improved from 0.78487 to 0.78655, saving model to model_fold_2_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 188ms/step - accuracy: 0.9116 - loss: 0.5686 - val_accuracy: 0.7866 - val_loss: 0.7127 - learning_rate: 9.5246e-04
# Epoch 9/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9080 - loss: 0.5623
# Epoch 9: val_accuracy did not improve from 0.78655
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9080 - loss: 0.5623 - val_accuracy: 0.7664 - val_loss: 0.8059 - learning_rate: 9.3822e-04
# 🔁 Phase 2: Fine-tuning top 30 base layers...
# Epoch 1/50
#   1/174 ━━━━━━━━━━━━━━━━━━━━ 52:15 18s/step - accuracy: 0.5000 - loss: 2.0149
# E0000 00:00:1747168629.546447     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747168629.742007     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.6954 - loss: 1.0939
# Epoch 1: val_accuracy improved from -inf to 0.82857, saving model to model_fold_2_fine_tuned.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 61s 249ms/step - accuracy: 0.6960 - loss: 1.0924 - val_accuracy: 0.8286 - val_loss: 0.6775
# Epoch 2/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8954 - loss: 0.5996
# Epoch 2: val_accuracy did not improve from 0.82857
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.8955 - loss: 0.5995 - val_accuracy: 0.7176 - val_loss: 0.8768
# Epoch 3/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9430 - loss: 0.5209
# Epoch 3: val_accuracy did not improve from 0.82857
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9431 - loss: 0.5208 - val_accuracy: 0.7563 - val_loss: 0.8352
# Epoch 4/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9616 - loss: 0.4837
# Epoch 4: val_accuracy did not improve from 0.82857
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9616 - loss: 0.4837 - val_accuracy: 0.7412 - val_loss: 0.8906
# 🧪 Evaluating on test set...
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#        close     1.0000    1.0000    1.0000       150
#      forward     0.9615    0.6667    0.7874       150
#         left     0.9797    0.9797    0.9797       148
#        right     0.7526    0.9865    0.8538       148
#
#     accuracy                         0.9077       596
#    macro avg     0.9235    0.9082    0.9052       596
# weighted avg     0.9238    0.9077    0.9052       596
#
# ✅ Fold 2 Test Accuracy: 0.9077 | F1 Score: 0.9052
#
# 🔁 Training on Fold 3/4
# Found 2781 images belonging to 4 classes.
# Found 593 images belonging to 4 classes.
# Found 595 images belonging to 4 classes.
# 🔼 Phase 1: Training classification head...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.5921 - loss: 1.0870
# Epoch 1: val_accuracy improved from -inf to 0.76897, saving model to model_fold_3_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 51s 239ms/step - accuracy: 0.5927 - loss: 1.0861 - val_accuracy: 0.7690 - val_loss: 0.7533 - learning_rate: 0.0010
# Epoch 2/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8240 - loss: 0.7162
# Epoch 2: val_accuracy did not improve from 0.76897
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.8241 - loss: 0.7161 - val_accuracy: 0.7504 - val_loss: 0.7704 - learning_rate: 9.9901e-04
# Epoch 3/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8644 - loss: 0.6395
# Epoch 3: val_accuracy improved from 0.76897 to 0.81788, saving model to model_fold_3_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 186ms/step - accuracy: 0.8644 - loss: 0.6395 - val_accuracy: 0.8179 - val_loss: 0.6961 - learning_rate: 9.9606e-04
# Epoch 4/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8887 - loss: 0.6028
# Epoch 4: val_accuracy improved from 0.81788 to 0.82799, saving model to model_fold_3_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.8886 - loss: 0.6028 - val_accuracy: 0.8280 - val_loss: 0.6869 - learning_rate: 9.9115e-04
# Epoch 5/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8949 - loss: 0.5796
# Epoch 5: val_accuracy did not improve from 0.82799
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.8948 - loss: 0.5796 - val_accuracy: 0.8010 - val_loss: 0.7297 - learning_rate: 9.8431e-04
# Epoch 6/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9073 - loss: 0.5638
# Epoch 6: val_accuracy did not improve from 0.82799
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.9073 - loss: 0.5638 - val_accuracy: 0.8027 - val_loss: 0.7226 - learning_rate: 9.7555e-04
# Epoch 7/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9135 - loss: 0.5544
# Epoch 7: val_accuracy improved from 0.82799 to 0.83137, saving model to model_fold_3_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 186ms/step - accuracy: 0.9135 - loss: 0.5544 - val_accuracy: 0.8314 - val_loss: 0.6765 - learning_rate: 9.6492e-04
# Epoch 8/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9203 - loss: 0.5438
# Epoch 8: val_accuracy did not improve from 0.83137
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9203 - loss: 0.5438 - val_accuracy: 0.8111 - val_loss: 0.7077 - learning_rate: 9.5246e-04
# Epoch 9/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9156 - loss: 0.5373
# Epoch 9: val_accuracy improved from 0.83137 to 0.83305, saving model to model_fold_3_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 186ms/step - accuracy: 0.9156 - loss: 0.5373 - val_accuracy: 0.8331 - val_loss: 0.6664 - learning_rate: 9.3822e-04
# Epoch 10/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9291 - loss: 0.5331
# Epoch 10: val_accuracy did not improve from 0.83305
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 182ms/step - accuracy: 0.9291 - loss: 0.5331 - val_accuracy: 0.8162 - val_loss: 0.7054 - learning_rate: 9.2224e-04
# Epoch 11/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9102 - loss: 0.5461
# Epoch 11: val_accuracy improved from 0.83305 to 0.84654, saving model to model_fold_3_phase1.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 187ms/step - accuracy: 0.9103 - loss: 0.5461 - val_accuracy: 0.8465 - val_loss: 0.6592 - learning_rate: 9.0460e-04
# Epoch 12/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9361 - loss: 0.5287
# Epoch 12: val_accuracy did not improve from 0.84654
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9360 - loss: 0.5288 - val_accuracy: 0.8398 - val_loss: 0.6680 - learning_rate: 8.8537e-04
# Epoch 13/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9164 - loss: 0.5471
# Epoch 13: val_accuracy did not improve from 0.84654
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9165 - loss: 0.5470 - val_accuracy: 0.8381 - val_loss: 0.6659 - learning_rate: 8.6462e-04
# Epoch 14/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9221 - loss: 0.5335
# Epoch 14: val_accuracy did not improve from 0.84654
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9221 - loss: 0.5335 - val_accuracy: 0.8246 - val_loss: 0.6596 - learning_rate: 8.4243e-04
# Epoch 15/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9301 - loss: 0.5268
# Epoch 15: val_accuracy did not improve from 0.84654
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9301 - loss: 0.5268 - val_accuracy: 0.8432 - val_loss: 0.6580 - learning_rate: 8.1889e-04
# Epoch 16/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9255 - loss: 0.5334
# Epoch 16: val_accuracy did not improve from 0.84654
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9255 - loss: 0.5334 - val_accuracy: 0.8280 - val_loss: 0.6754 - learning_rate: 7.9410e-04
# Epoch 17/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9400 - loss: 0.5099
# Epoch 17: val_accuracy did not improve from 0.84654
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.9400 - loss: 0.5100 - val_accuracy: 0.8246 - val_loss: 0.6696 - learning_rate: 7.6815e-04
# Epoch 18/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9431 - loss: 0.5164
# Epoch 18: val_accuracy did not improve from 0.84654
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9430 - loss: 0.5164 - val_accuracy: 0.8297 - val_loss: 0.6740 - learning_rate: 7.4114e-04
# Epoch 19/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9405 - loss: 0.5149
# Epoch 19: val_accuracy did not improve from 0.84654
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9405 - loss: 0.5150 - val_accuracy: 0.8297 - val_loss: 0.6823 - learning_rate: 7.1318e-04
# Epoch 20/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9352 - loss: 0.5243
# Epoch 20: val_accuracy did not improve from 0.84654
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 182ms/step - accuracy: 0.9352 - loss: 0.5243 - val_accuracy: 0.8094 - val_loss: 0.7060 - learning_rate: 6.8438e-04
# 🔁 Phase 2: Fine-tuning top 30 base layers...
# Epoch 1/50
# 141/174 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - accuracy: 0.6493 - loss: 1.2271
# E0000 00:00:1747169482.316567     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747169482.512508     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6732 - loss: 1.1692
# Epoch 1: val_accuracy improved from -inf to 0.82293, saving model to model_fold_3_fine_tuned.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 61s 245ms/step - accuracy: 0.6739 - loss: 1.1676 - val_accuracy: 0.8229 - val_loss: 0.7168
# Epoch 2/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8975 - loss: 0.6312
# Epoch 2: val_accuracy did not improve from 0.82293
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.8976 - loss: 0.6311 - val_accuracy: 0.8094 - val_loss: 0.8512
# Epoch 3/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9267 - loss: 0.5733
# Epoch 3: val_accuracy improved from 0.82293 to 0.83980, saving model to model_fold_3_fine_tuned.keras
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 186ms/step - accuracy: 0.9267 - loss: 0.5733 - val_accuracy: 0.8398 - val_loss: 0.8160
# Epoch 4/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9365 - loss: 0.5395
# Epoch 4: val_accuracy did not improve from 0.83980
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9365 - loss: 0.5395 - val_accuracy: 0.8398 - val_loss: 0.8268
# 🧪 Evaluating on test set...
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 100ms/step
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#        close     0.9934    1.0000    0.9967       150
#      forward     0.6816    0.9384    0.7896       146
#         left     0.7206    0.9866    0.8329       149
#        right     0.8718    0.2267    0.3598       150
#
#     accuracy                         0.7866       595
#    macro avg     0.8168    0.7879    0.7447       595
# weighted avg     0.8179    0.7866    0.7443       595
#
# ✅ Fold 3 Test Accuracy: 0.7866 | F1 Score: 0.7447
#
# 🔁 Training on Fold 4/4
# Found 2788 images belonging to 4 classes.
# Found 592 images belonging to 4 classes.
# Found 589 images belonging to 4 classes.
# 🔼 Phase 1: Training classification head...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.5431 - loss: 1.1983
# Epoch 1: val_accuracy improved from -inf to 0.77872, saving model to model_fold_4_phase1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 222ms/step - accuracy: 0.5437 - loss: 1.1970 - val_accuracy: 0.7787 - val_loss: 0.7325 - learning_rate: 0.0010
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7865 - loss: 0.7500
# Epoch 2: val_accuracy improved from 0.77872 to 0.83277, saving model to model_fold_4_phase1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.7866 - loss: 0.7498 - val_accuracy: 0.8328 - val_loss: 0.6780 - learning_rate: 9.9901e-04
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8576 - loss: 0.6553
# Epoch 3: val_accuracy improved from 0.83277 to 0.87669, saving model to model_fold_4_phase1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.8577 - loss: 0.6552 - val_accuracy: 0.8767 - val_loss: 0.6157 - learning_rate: 9.9606e-04
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8796 - loss: 0.6122
# Epoch 4: val_accuracy improved from 0.87669 to 0.88176, saving model to model_fold_4_phase1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.8796 - loss: 0.6122 - val_accuracy: 0.8818 - val_loss: 0.6147 - learning_rate: 9.9115e-04
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8804 - loss: 0.6061
# Epoch 5: val_accuracy did not improve from 0.88176
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.8804 - loss: 0.6060 - val_accuracy: 0.8818 - val_loss: 0.6173 - learning_rate: 9.8431e-04
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9018 - loss: 0.5777
# Epoch 6: val_accuracy did not improve from 0.88176
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9018 - loss: 0.5777 - val_accuracy: 0.8395 - val_loss: 0.6458 - learning_rate: 9.7555e-04
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9059 - loss: 0.5636
# Epoch 7: val_accuracy improved from 0.88176 to 0.89865, saving model to model_fold_4_phase1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9059 - loss: 0.5636 - val_accuracy: 0.8986 - val_loss: 0.5818 - learning_rate: 9.6492e-04
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9091 - loss: 0.5587
# Epoch 8: val_accuracy improved from 0.89865 to 0.90372, saving model to model_fold_4_phase1.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9091 - loss: 0.5587 - val_accuracy: 0.9037 - val_loss: 0.5879 - learning_rate: 9.5246e-04
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9149 - loss: 0.5466
# Epoch 9: val_accuracy did not improve from 0.90372
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9150 - loss: 0.5465 - val_accuracy: 0.8936 - val_loss: 0.5940 - learning_rate: 9.3822e-04
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9197 - loss: 0.5532
# Epoch 10: val_accuracy did not improve from 0.90372
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 182ms/step - accuracy: 0.9197 - loss: 0.5532 - val_accuracy: 0.8784 - val_loss: 0.6039 - learning_rate: 9.2224e-04
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9248 - loss: 0.5407
# Epoch 11: val_accuracy did not improve from 0.90372
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9248 - loss: 0.5407 - val_accuracy: 0.8970 - val_loss: 0.5858 - learning_rate: 9.0460e-04
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9197 - loss: 0.5373
# Epoch 12: val_accuracy did not improve from 0.90372
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 181ms/step - accuracy: 0.9197 - loss: 0.5372 - val_accuracy: 0.8851 - val_loss: 0.5947 - learning_rate: 8.8537e-04
# 🔁 Phase 2: Fine-tuning top 30 base layers...
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.7154 - loss: 1.0220
# Epoch 1: val_accuracy improved from -inf to 0.84966, saving model to model_fold_4_fine_tuned.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 59s 231ms/step - accuracy: 0.7159 - loss: 1.0208 - val_accuracy: 0.8497 - val_loss: 0.6778
# Epoch 2/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8984 - loss: 0.6048
# Epoch 2: val_accuracy did not improve from 0.84966
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.8984 - loss: 0.6047 - val_accuracy: 0.8311 - val_loss: 0.7164
# Epoch 3/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9435 - loss: 0.5353
# Epoch 3: val_accuracy improved from 0.84966 to 0.87162, saving model to model_fold_4_fine_tuned.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.9435 - loss: 0.5353 - val_accuracy: 0.8716 - val_loss: 0.6494
# Epoch 4/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9564 - loss: 0.4928
# Epoch 4: val_accuracy improved from 0.87162 to 0.87669, saving model to model_fold_4_fine_tuned.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.9564 - loss: 0.4928 - val_accuracy: 0.8767 - val_loss: 0.6418
# Epoch 5/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9657 - loss: 0.4819
# Epoch 5: val_accuracy improved from 0.87669 to 0.92399, saving model to model_fold_4_fine_tuned.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.9657 - loss: 0.4819 - val_accuracy: 0.9240 - val_loss: 0.5766
# Epoch 6/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9786 - loss: 0.4684
# Epoch 6: val_accuracy did not improve from 0.92399
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9786 - loss: 0.4683 - val_accuracy: 0.9088 - val_loss: 0.5785
# Epoch 7/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9790 - loss: 0.4531
# Epoch 7: val_accuracy did not improve from 0.92399
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.9790 - loss: 0.4531 - val_accuracy: 0.9155 - val_loss: 0.5787
# Epoch 8/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9792 - loss: 0.4449
# Epoch 8: val_accuracy improved from 0.92399 to 0.92736, saving model to model_fold_4_fine_tuned.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.9792 - loss: 0.4449 - val_accuracy: 0.9274 - val_loss: 0.5516
# Epoch 9/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9825 - loss: 0.4342
# Epoch 9: val_accuracy improved from 0.92736 to 0.94932, saving model to model_fold_4_fine_tuned.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9826 - loss: 0.4342 - val_accuracy: 0.9493 - val_loss: 0.5192
# Epoch 10/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9863 - loss: 0.4341
# Epoch 10: val_accuracy did not improve from 0.94932
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9863 - loss: 0.4341 - val_accuracy: 0.9392 - val_loss: 0.5393
# Epoch 11/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9857 - loss: 0.4347
# Epoch 11: val_accuracy did not improve from 0.94932
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9857 - loss: 0.4347 - val_accuracy: 0.9341 - val_loss: 0.5455
# Epoch 12/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9913 - loss: 0.4203
# Epoch 12: val_accuracy did not improve from 0.94932
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9913 - loss: 0.4203 - val_accuracy: 0.9493 - val_loss: 0.5143
# Epoch 13/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9934 - loss: 0.4149
# Epoch 13: val_accuracy did not improve from 0.94932
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.9934 - loss: 0.4149 - val_accuracy: 0.9426 - val_loss: 0.5181
# Epoch 14/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9939 - loss: 0.4064
# Epoch 14: val_accuracy did not improve from 0.94932
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 182ms/step - accuracy: 0.9939 - loss: 0.4064 - val_accuracy: 0.9358 - val_loss: 0.5374
# Epoch 15/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9852 - loss: 0.4189
# Epoch 15: val_accuracy did not improve from 0.94932
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 183ms/step - accuracy: 0.9852 - loss: 0.4188 - val_accuracy: 0.9358 - val_loss: 0.5431
# 🧪 Evaluating on test set...
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 103ms/step
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#        close     0.9613    1.0000    0.9803       149
#      forward     0.9238    0.6599    0.7698       147
#         left     0.9818    0.7200    0.8308       150
#        right     0.6393    0.9790    0.7735       143
#
#     accuracy                         0.8387       589
#    macro avg     0.8765    0.8397    0.8386       589
# weighted avg     0.8790    0.8387    0.8395       589
#
# ✅ Fold 4 Test Accuracy: 0.8387 | F1 Score: 0.8386
#
# 📊 Average Test Accuracy across 4 folds: 0.8439 ± 0.0430

# %%
import os
import tensorflow as tf

# === CONFIGURATION ===
KERAS_MODEL_DIR = "./"  # Folder containing your .keras files
TFLITE_OUTPUT_DIR = "./tflite_models"
os.makedirs(TFLITE_OUTPUT_DIR, exist_ok=True)

# === Convert all .keras models
keras_models = [f for f in os.listdir(KERAS_MODEL_DIR) if f.endswith(".keras")]

for keras_file in keras_models:
    keras_path = os.path.join(KERAS_MODEL_DIR, keras_file)
    tflite_filename = keras_file.replace(".keras", ".tflite")
    tflite_path = os.path.join(TFLITE_OUTPUT_DIR, tflite_filename)

    print(f"🔄 Converting: {keras_file} → {tflite_filename}")

    # Load model
    model = tf.keras.models.load_model(keras_path)

    # Convert to TFLite (FP32)
    converter = tf.lite.TFLiteConverter.from_keras_model(model)

    # Optimize for size/speed (optional but recommended for Raspberry Pi)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]

    # Convert
    tflite_model = converter.convert()

    # Save
    with open(tflite_path, 'wb') as f:
        f.write(tflite_model)

    print(f"✅ Saved: {tflite_path}")

print("\n📁 All models converted to:", TFLITE_OUTPUT_DIR)
# Out:
# 🔄 Converting: model_fold_4_fine_tuned.keras → model_fold_4_fine_tuned.tflite
# Saved artifact at '/tmp/tmp2zbfpze9'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_3')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   137106027719440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106027711952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106027723280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106027715600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106027712528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106027716752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106033887952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106033886224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106027723856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106027720592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106033886800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106033899472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106033893712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106033897936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106033889488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106033897744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106033895632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106028167248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106033895440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106033893328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106028178000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106028182224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106028176080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106028168208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106028173584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106028169744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106028181072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106028173392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106028170320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106028174160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137105763264528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137105763267216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137105763264144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137105763258384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137105763259536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137105763267408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137105763256080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137105763268368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137105763266064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137105763258000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106059275216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106059278864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106059276176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106059278096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106059274448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106059277904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137106059270800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137